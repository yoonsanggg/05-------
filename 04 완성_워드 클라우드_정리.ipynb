# %% [markdown]
# ###  워드 클라우드

# %% [markdown]
# #### 기사 1개만 워드클라우드

# %%
# 샘플 뉴스에서 기사 1개만 명사만 뽑기
import pandas as pd
from konlpy.tag import Okt

# %%
sample=pd.read_csv('./data/전처리_샘플뉴스.csv')

# %%
okt=Okt()
words=okt.nouns(sample['text'][2])

# %%
str_words=' '.join(words)

# %%
str_words
# Out:
# '곳곳 수해 초비상 오전 충남 천안 아산 지역 호우경보 발령 가운데 날 오후 아산시 온천 관광 호텔 사거리 도로 침수 독자 제공 뉴시스 지난 사흘 동안 물폭탄 수도권 등 중부지방 인명 재산 피해 속출 중부지방 비 것 예보 각별 주의 요구 중앙 재난 안전 대책 본부 중 대본 각 지방자치단체 계속 게릴라 집중호우 날 오후 현재 경기 평택 가평 명 명 실종 신고 사람 경기 포천 명 과 가평 명 충남 아산 명 명 날 오전 평택시 청북읍 후 사리 반도체 장비 부품 공장 건물 뒤편 야산 가건물 천막 소방 당국 사고 후 만인 낮 토사 씨 등 근로자 명 구조해 인근 병원 근로자 명 끝내 오전 가평읍 산 유리 산사태 토사 펜션 무동 펜션 주인 여 과 딸 손자 직원 명 베트남인 이 매몰 오후 현재 주인 가족 명의 시신 수습 밭 급류 린 가평군 청평면 농민 등 날 실종자 명 사망자 더 늘 수 사흘 중부지방 강타 집중호우 사망 실종자 명 경기도 가평군 가평읍 산 유리 펜션 토사 소방 당국 중장비 동원 작업 벌이 뉴스 경기 충북 강원 가구 명의 재민 발생 산사태 하천 제방 범람 주택 침수 등 일시 대피 인원 이 지역 명 달 시설 물 피해 주택 채 비닐하우스 동이 물 산사태 건 하천 저수지 범람 건 발생 도로 교량 건 파손 농경 침수 전국 개 댐 중 충주댐 대청댐 등 곳 물 감당 방류 경기 여주 청미 복 하천 남양주 왕숙천 포천 영평 홍수 보가 발령 전날 오후 기해 위기 단계 최고 수준 단계 심각 로 격상 중 대본 달 집중호우 대처 및 피해 상황 긴급 점검 회의 문재인 대통령 날 피해 상황 보고 인명 피해 추가 발생 정부 지자체 총력 고 당부 기상청 제 호 태풍 하구핏 의 영향 중부지방 중심 비 것 예상 강수량 서울 경기 강원 영서 충청 북부 서해 도 지역 곳 이상 강원영동 충청 남부 경북 북부 지역 곳 이상 서울 경기도 강원 영서 지방 줄곧 비 것 송민섭 남혜정 박현준 기자 세상 눈 세계 일보'

# %% [markdown]
# #### 워드 클라우드 (1)
# wc.generate(str자료)함수는 str형식으로 자료를 넣어줌

# %%
#워드 클라우드
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)


wc = WordCloud("C:/windows/fonts/malgun.ttf",
               background_color = "white",
               max_words = 2000)
               #stopwords = stopwords)
wc = wc.generate(str_words) # str자료만 가능, list자료는 안됨

#matplotlib로 시작화(1)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
#matplotlib로 시작화(2)
plt.figure(figsize = (12, 12))
plt.imshow(wc) #interpolation = "bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# #### 워드 클라우드 (2)
# `WordCloud.generate_from_frequencies`에 {단어:빈도수} 형식의 딕셔너리를 넣어주면 워드 클라우드가 생성됩니다

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np

#단어빈도수 세기
sample=pd.read_csv('./data/전처리_샘플뉴스.csv')
okt=Okt()
words=okt.nouns(sample['text'][2]) 
words
# Out:
# ['곳곳',
#  '수해',
#  '초비상',
#  '오전',
#  '충남',
#  '천안',
#  '아산',
#  '지역',
#  '호우경보',
#  '발령',
#  '가운데',
#  '날',
#  '오후',
#  '아산시',
#  '온천',
#  '관광',
#  '호텔',
#  '사거리',
#  '도로',
#  '침수',
#  '독자',
#  '제공',
#  '뉴시스',
#  '지난',
#  '사흘',
#  '동안',
#  '물폭탄',
#  '수도권',
#  '등',
#  '중부지방',
#  '인명',
#  '재산',
#  '피해',
#  '속출',
#  '중부지방',
#  '비',
#  '것',
#  '예보',
#  '각별',
#  '주의',
#  '요구',
#  '중앙',
#  '재난',
#  '안전',
#  '대책',
#  '본부',
#  '중',
#  '대본',
#  '각',
#  '지방자치단체',
#  '계속',
#  '게릴라',
#  '집중호우',
#  '날',
#  '오후',
#  '현재',
#  '경기',
#  '평택',
#  '가평',
#  '명',
#  '명',
#  '실종',
#  '신고',
#  '사람',
#  '경기',
#  '포천',
#  '명',
#  '과',
#  '가평',
#  '명',
#  '충남',
#  '아산',
#  '명',
#  '명',
#  '날',
#  '오전',
#  '평택시',
#  '청북읍',
#  '후',
#  '사리',
#  '반도체',
#  '장비',
#  '부품',
#  '공장',
#  '건물',
#  '뒤편',
#  '야산',
#  '가건물',
#  '천막',
#  '소방',
#  '당국',
#  '사고',
#  '후',
#  '만인',
#  '낮',
#  '토사',
#  '씨',
#  '등',
#  '근로자',
#  '명',
#  '구조해',
#  '인근',
#  '병원',
#  '근로자',
#  '명',
#  '끝내',
#  '오전',
#  '가평읍',
#  '산',
#  '유리',
#  '산사태',
#  '토사',
#  '펜션',
#  '무동',
#  '펜션',
#  '주인',
#  '여',
#  '과',
#  '딸',
#  '손자',
#  '직원',
#  '명',
#  '베트남인',
#  '이',
#  '매몰',
#  '오후',
#  '현재',
#  '주인',
#  '가족',
#  '명의',
#  '시신',
#  '수습',
#  '밭',
#  '급류',
#  '린',
#  '가평군',
#  '청평면',
#  '농민',
#  '등',
#  '날',
#  '실종자',
#  '명',
#  '사망자',
#  '더',
#  '늘',
#  '수',
#  '사흘',
#  '중부지방',
#  '강타',
#  '집중호우',
#  '사망',
#  '실종자',
#  '명',
#  '경기도',
#  '가평군',
#  '가평읍',
#  '산',
#  '유리',
#  '펜션',
#  '토사',
#  '소방',
#  '당국',
#  '중장비',
#  '동원',
#  '작업',
#  '벌이',
#  '뉴스',
#  '경기',
#  '충북',
#  '강원',
#  '가구',
#  '명의',
#  '재민',
#  '발생',
#  '산사태',
#  '하천',
#  '제방',
#  '범람',
#  '주택',
#  '침수',
#  '등',
#  '일시',
#  '대피',
#  '인원',
#  '이',
#  '지역',
#  '명',
#  '달',
#  '시설',
#  '물',
#  '피해',
#  '주택',
#  '채',
#  '비닐하우스',
#  '동이',
#  '물',
#  '산사태',
#  '건',
#  '하천',
#  '저수지',
#  '범람',
#  '건',
#  '발생',
#  '도로',
#  '교량',
#  '건',
#  '파손',
#  '농경',
#  '침수',
#  '전국',
#  '개',
#  '댐',
#  '중',
#  '충주댐',
#  '대청댐',
#  '등',
#  '곳',
#  '물',
#  '감당',
#  '방류',
#  '경기',
#  '여주',
#  '청미',
#  '복',
#  '하천',
#  '남양주',
#  '왕숙천',
#  '포천',
#  '영평',
#  '홍수',
#  '보가',
#  '발령',
#  '전날',
#  '오후',
#  '기해',
#  '위기',
#  '단계',
#  '최고',
#  '수준',
#  '단계',
#  '심각',
#  '로',
#  '격상',
#  '중',
#  '대본',
#  '달',
#  '집중호우',
#  '대처',
#  '및',
#  '피해',
#  '상황',
#  '긴급',
#  '점검',
#  '회의',
#  '문재인',
#  '대통령',
#  '날',
#  '피해',
#  '상황',
#  '보고',
#  '인명',
#  '피해',
#  '추가',
#  '발생',
#  '정부',
#  '지자체',
#  '총력',
#  '고',
#  '당부',
#  '기상청',
#  '제',
#  '호',
#  '태풍',
#  '하구핏',
#  '의',
#  '영향',
#  '중부지방',
#  '중심',
#  '비',
#  '것',
#  '예상',
#  '강수량',
#  '서울',
#  '경기',
#  '강원',
#  '영서',
#  '충청',
#  '북부',
#  '서해',
#  '도',
#  '지역',
#  '곳',
#  '이상',
#  '강원영동',
#  '충청',
#  '남부',
#  '경북',
#  '북부',
#  '지역',
#  '곳',
#  '이상',
#  '서울',
#  '경기도',
#  '강원',
#  '영서',
#  '지방',
#  '줄곧',
#  '비',
#  '것',
#  '송민섭',
#  '남혜정',
#  '박현준',
#  '기자',
#  '세상',
#  '눈',
#  '세계',
#  '일보']

# %%
#단어 빈도수 세기
counter = Counter(words)
counter
# Out:
# Counter({'명': 12,
#          '날': 5,
#          '등': 5,
#          '피해': 5,
#          '경기': 5,
#          '지역': 4,
#          '오후': 4,
#          '중부지방': 4,
#          '오전': 3,
#          '침수': 3,
#          '비': 3,
#          '것': 3,
#          '중': 3,
#          '집중호우': 3,
#          '토사': 3,
#          '산사태': 3,
#          '펜션': 3,
#          '강원': 3,
#          '발생': 3,
#          '하천': 3,
#          '물': 3,
#          '건': 3,
#          '곳': 3,
#          '충남': 2,
#          '아산': 2,
#          '발령': 2,
#          '도로': 2,
#          '사흘': 2,
#          '인명': 2,
#          '대본': 2,
#          '현재': 2,
#          '가평': 2,
#          '포천': 2,
#          '과': 2,
#          '후': 2,
#          '소방': 2,
#          '당국': 2,
#          '근로자': 2,
#          '가평읍': 2,
#          '산': 2,
#          '유리': 2,
#          '주인': 2,
#          '이': 2,
#          '명의': 2,
#          '가평군': 2,
#          '실종자': 2,
#          '경기도': 2,
#          '범람': 2,
#          '주택': 2,
#          '달': 2,
#          '단계': 2,
#          '상황': 2,
#          '서울': 2,
#          '영서': 2,
#          '충청': 2,
#          '북부': 2,
#          '이상': 2,
#          '곳곳': 1,
#          '수해': 1,
#          '초비상': 1,
#          '천안': 1,
#          '호우경보': 1,
#          '가운데': 1,
#          '아산시': 1,
#          '온천': 1,
#          '관광': 1,
#          '호텔': 1,
#          '사거리': 1,
#          '독자': 1,
#          '제공': 1,
#          '뉴시스': 1,
#          '지난': 1,
#          '동안': 1,
#          '물폭탄': 1,
#          '수도권': 1,
#          '재산': 1,
#          '속출': 1,
#          '예보': 1,
#          '각별': 1,
#          '주의': 1,
#          '요구': 1,
#          '중앙': 1,
#          '재난': 1,
#          '안전': 1,
#          '대책': 1,
#          '본부': 1,
#          '각': 1,
#          '지방자치단체': 1,
#          '계속': 1,
#          '게릴라': 1,
#          '평택': 1,
#          '실종': 1,
#          '신고': 1,
#          '사람': 1,
#          '평택시': 1,
#          '청북읍': 1,
#          '사리': 1,
#          '반도체': 1,
#          '장비': 1,
#          '부품': 1,
#          '공장': 1,
#          '건물': 1,
#          '뒤편': 1,
#          '야산': 1,
#          '가건물': 1,
#          '천막': 1,
#          '사고': 1,
#          '만인': 1,
#          '낮': 1,
#          '씨': 1,
#          '구조해': 1,
#          '인근': 1,
#          '병원': 1,
#          '끝내': 1,
#          '무동': 1,
#          '여': 1,
#          '딸': 1,
#          '손자': 1,
#          '직원': 1,
#          '베트남인': 1,
#          '매몰': 1,
#          '가족': 1,
#          '시신': 1,
#          '수습': 1,
#          '밭': 1,
#          '급류': 1,
#          '린': 1,
#          '청평면': 1,
#          '농민': 1,
#          '사망자': 1,
#          '더': 1,
#          '늘': 1,
#          '수': 1,
#          '강타': 1,
#          '사망': 1,
#          '중장비': 1,
#          '동원': 1,
#          '작업': 1,
#          '벌이': 1,
#          '뉴스': 1,
#          '충북': 1,
#          '가구': 1,
#          '재민': 1,
#          '제방': 1,
#          '일시': 1,
#          '대피': 1,
#          '인원': 1,
#          '시설': 1,
#          '채': 1,
#          '비닐하우스': 1,
#          '동이': 1,
#          '저수지': 1,
#          '교량': 1,
#          '파손': 1,
#          '농경': 1,
#          '전국': 1,
#          '개': 1,
#          '댐': 1,
#          '충주댐': 1,
#          '대청댐': 1,
#          '감당': 1,
#          '방류': 1,
#          '여주': 1,
#          '청미': 1,
#          '복': 1,
#          '남양주': 1,
#          '왕숙천': 1,
#          '영평': 1,
#          '홍수': 1,
#          '보가': 1,
#          '전날': 1,
#          '기해': 1,
#          '위기': 1,
#          '최고': 1,
#          '수준': 1,
#          '심각': 1,
#          '로': 1,
#          '격상': 1,
#          '대처': 1,
#          '및': 1,
#          '긴급': 1,
#          '점검': 1,
#          '회의': 1,
#          '문재인': 1,
#          '대통령': 1,
#          '보고': 1,
#          '추가': 1,
#          '정부': 1,
#          '지자체': 1,
#          '총력': 1,
#          '고': 1,
#          '당부': 1,
#          '기상청': 1,
#          '제': 1,
#          '호': 1,
#          '태풍': 1,
#          '하구핏': 1,
#          '의': 1,
#          '영향': 1,
#          '중심': 1,
#          '예상': 1,
#          '강수량': 1,
#          '서해': 1,
#          '도': 1,
#          '강원영동': 1,
#          '남부': 1,
#          '경북': 1,
#          '지방': 1,
#          '줄곧': 1,
#          '송민섭': 1,
#          '남혜정': 1,
#          '박현준': 1,
#          '기자': 1,
#          '세상': 1,
#          '눈': 1,
#          '세계': 1,
#          '일보': 1})

# %%
#워드 클라우드

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)


wc = WordCloud("C:/windows/fonts/malgun.ttf",
               background_color = "white",
               max_words = 2000)
               #stopwords = stopwords)
wc = wc.generate_from_frequencies(counter) # str자료만 가능, list자료는 안됨

#matplotlib로 시작화(1)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# ### 실루엣 그리기

# %%
from PIL import Image
import numpy as np
 
im = Image.open('./img03.jpg') # 이미지 파일 읽어오기
mask_arr = np.array(im) # 픽셀 값 배열 형태 변환
mask_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
#워드 클라우드

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)

img = plt.imread('./img03.jpg')
mask_arr = np.array(img) # 픽셀 값 배열 형태 변환


wc = WordCloud("C:/windows/fonts/malgun.ttf",
               background_color = "white",
               max_words = 2000,
               mask=mask_arr)
               #stopwords = stopwords)
wc = wc.generate_from_frequencies(counter) # str자료만 가능, list자료는 안됨

#matplotlib로 시작화(1)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %% [markdown]
# ### [미션] 모든 기사를 합쳐 워드 클라우드

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np

#단어빈도수 세기
sample=pd.read_csv('./data/전처리_샘플뉴스.csv')
okt=Okt()

# %%
sample.head(3)
# Out:
#                                    title  \
# 0  방역 2.5단계 뒤 을씨년스럽게 변한 '스벅'···별천지된 '파바'
# 1          "기적 같은 선방"이라지만...현장은 성한 곳이 없다
# 2           13일까지 장맛비… 사흘간 물폭탄 사망·실종 25명
#
#                                                 text  \
# 0  서울의 밤이 달라졌다. 수도권을 대상으로 이른바 ‘사회적 거리두기 2.5단계’가 시...
# 1  “50년 동안 사업하면서 소위 ‘깡통’을 세 번 차고도 재기했는데, 이번 위기는 정...
# 2  곳곳 수해 초비상 \r\n\r\n    3일 오전 충남 천안과 아산지역에 호우경보가...
#
#                                                  url media        date
# 0  https://news.naver.com/main/read.nhn?mode=LPOD...  중앙일보  2020-08-31
# 1  https://news.naver.com/main/read.nhn?mode=LPOD...  한국일보  2020-08-03
# 2  https://news.naver.com/main/read.nhn?mode=LPOD...  세계일보  2020-08-04

# %%
words=okt.nouns(' '.join(sample['text']))

# %%
counter=Counter(words)

# %%
counter
# Out:
# Counter({'명': 24,
#          '고': 21,
#          '것': 21,
#          '코로나': 19,
#          '오후': 18,
#          '대출': 17,
#          '금리': 17,
#          '등': 15,
#          '이': 15,
#          '수': 14,
#          '말': 13,
#          '달': 13,
#          '비': 13,
#          '업계': 12,
#          '씨': 11,
#          '매출': 11,
#          '며': 11,
#          '중': 11,
#          '경기': 11,
#          '건': 10,
#          '결혼식': 10,
#          '고객': 10,
#          '이상': 10,
#          '지난': 10,
#          '업체': 10,
#          '예상': 10,
#          '피해': 10,
#          '서울': 9,
#          '문': 9,
#          '때문': 9,
#          '지역': 9,
#          '곳': 9,
#          '관계자': 9,
#          '재': 9,
#          '상황': 9,
#          '날': 8,
#          '매장': 8,
#          '로': 8,
#          '기자': 8,
#          '경제': 8,
#          '하반기': 8,
#          '산사태': 8,
#          '온라인': 7,
#          '개': 7,
#          '이후': 7,
#          '기업': 7,
#          '산업': 7,
#          '외식': 7,
#          '정부': 7,
#          '발생': 7,
#          '신용': 7,
#          '손님': 6,
#          '오전': 6,
#          '경기도': 6,
#          '현장': 6,
#          '위기': 6,
#          '자동차': 6,
#          '대비': 6,
#          '기록': 6,
#          '우려': 6,
#          '더': 6,
#          '은행': 6,
#          '중부지방': 6,
#          '주택': 6,
#          '단계': 5,
#          '술집': 5,
#          '금지': 5,
#          '시작': 5,
#          '안': 5,
#          '직원': 5,
#          '빚': 5,
#          '확산': 5,
#          '본부': 5,
#          '전국': 5,
#          '다시': 5,
#          '수준': 5,
#          '돈': 5,
#          '여행': 5,
#          '청와대': 5,
#          '상반기': 5,
#          '전망': 5,
#          '감소': 5,
#          '전': 5,
#          '국내': 5,
#          '평균': 5,
#          '사상': 5,
#          '집중호우': 5,
#          '사망': 5,
#          '태풍': 5,
#          '북부': 5,
#          '최저': 5,
#          '역대': 5,
#          '라며': 4,
#          '포장': 4,
#          '일부': 4,
#          '를': 4,
#          '판매': 4,
#          '카페': 4,
#          '발길': 4,
#          '우리': 4,
#          '게': 4,
#          '늘': 4,
#          '하객': 4,
#          '이번': 4,
#          '한국': 4,
#          '대표': 4,
#          '은': 4,
#          '중앙': 4,
#          '대책': 4,
#          '및': 4,
#          '못': 4,
#          '협력': 4,
#          '선방': 4,
#          '사람': 4,
#          '수치': 4,
#          '올해': 4,
#          '폭': 4,
#          '지수': 4,
#          '재난': 4,
#          '면세점': 4,
#          '얘기': 4,
#          '수요': 4,
#          '호텔': 4,
#          '부품': 4,
#          '도': 4,
#          '인명': 4,
#          '실종': 4,
#          '강원': 4,
#          '물': 4,
#          '전남': 4,
#          '예금': 4,
#          '가계': 4,
#          '증가': 4,
#          '대상': 3,
#          '거리': 3,
#          '시행': 3,
#          '중심': 3,
#          '식당': 3,
#          '취식': 3,
#          '장사': 3,
#          '집': 3,
#          '인근': 3,
#          '사장': 3,
#          '가게': 3,
#          '시간': 3,
#          '액': 3,
#          '그': 3,
#          '한숨': 3,
#          '규모': 3,
#          '배달': 3,
#          '눈': 3,
#          '사이': 3,
#          '프랜차이즈': 3,
#          '커피전문점': 3,
#          '생중계': 3,
#          '설명': 3,
#          '또': 3,
#          '다른': 3,
#          '낮': 3,
#          '차': 3,
#          '나': 3,
#          '토로': 3,
#          '직접': 3,
#          '대본': 3,
#          '동안': 3,
#          '조사': 3,
#          '무단': 3,
#          '배포': 3,
#          '지난달': 3,
#          '공장': 3,
#          '절반': 3,
#          '데': 3,
#          '근로자': 3,
#          '여파': 3,
#          '버티고': 3,
#          '항공': 3,
#          '불어': 3,
#          '의': 3,
#          '터널': 3,
#          '현실': 3,
#          '수출': 3,
#          '연속': 3,
#          '현재': 3,
#          '걱정': 3,
#          '처음': 3,
#          '원금': 3,
#          '시장': 3,
#          '포인트': 3,
#          '후': 3,
#          '회복': 3,
#          '역시': 3,
#          '셈': 3,
#          '상품': 3,
#          '속출': 3,
#          '발령': 3,
#          '침수': 3,
#          '사흘': 3,
#          '토사': 3,
#          '펜션': 3,
#          '하천': 3,
#          '최고': 3,
#          '기상청': 3,
#          '영향': 3,
#          '영서': 3,
#          '지방': 3,
#          '장마': 3,
#          '해상': 3,
#          '장미': 3,
#          '경남': 3,
#          '남해안': 3,
#          '제주도': 3,
#          '주식': 3,
#          '전월': 3,
#          '수도권': 2,
#          '두기': 2,
#          '음식점': 2,
#          '내': 2,
#          '전후': 2,
#          '위주': 2,
#          '마감': 2,
#          '맥줏집': 2,
#          '평소': 2,
#          '김모': 2,
#          '달라': 2,
#          '영업': 2,
#          '다음': 2,
#          '원래': 2,
#          '가장': 2,
#          '층': 2,
#          '대형': 2,
#          '아예': 2,
#          '뿐': 2,
#          '중구': 2,
#          '전체': 2,
#          '온종일': 2,
#          '모습': 2,
#          '댓글': 2,
#          '축의금': 2,
#          '계좌': 2,
#          '정자동': 2,
#          '스타벅스': 2,
#          '가족': 2,
#          '지인': 2,
#          '커피': 2,
#          '빵': 2,
#          '이용': 2,
#          '개인': 2,
#          '제과점': 2,
#          '마찬가지': 2,
#          '드라이브': 2,
#          '스루': 2,
#          '차량': 2,
#          '대가': 2,
#          '줄줄이': 2,
#          '줄': 2,
#          '방역': 2,
#          '부부': 2,
#          '최근': 2,
#          '하자': 2,
#          '중계': 2,
#          '주소': 2,
#          '신부': 2,
#          '축가': 2,
#          '사태': 2,
#          '생각': 2,
#          '대만': 2,
#          '한편': 2,
#          '방': 2,
#          '기준': 2,
#          '시설': 2,
#          '만큼': 2,
#          '일보': 2,
#          '세': 2,
#          '번': 2,
#          '목소리': 2,
#          '요즘': 2,
#          '률': 2,
#          '생산': 2,
#          '개월': 2,
#          '금융위기': 2,
#          '모두': 2,
#          '온': 2,
#          '장기': 2,
#          '실물': 2,
#          '문재인': 2,
#          '대통령': 2,
#          '숫자': 2,
#          '악': 2,
#          '낙관': 2,
#          '우리나라': 2,
#          '성장': 2,
#          '작년': 2,
#          '자릿수': 2,
#          '반등': 2,
#          '마이너스': 2,
#          '언제': 2,
#          '체감': 2,
#          '어려움': 2,
#          '외면': 2,
#          '보고': 2,
#          '집계': 2,
#          '몇': 2,
#          '음악': 2,
#          '가까이': 2,
#          '긴급': 2,
#          '지급': 2,
#          '분위기': 2,
#          '보따리': 2,
#          '입국': 2,
#          '회사': 2,
#          '입지': 2,
#          '중단': 2,
#          '가량': 2,
#          '관련': 2,
#          '여행사': 2,
#          '해외': 2,
#          '지난해': 2,
#          '적자': 2,
#          '연간': 2,
#          '유동성': 2,
#          '채': 2,
#          '자금': 2,
#          '포스코': 2,
#          '첫': 2,
#          '건설': 2,
#          '지속': 2,
#          '세계': 2,
#          '충남': 2,
#          '아산': 2,
#          '도로': 2,
#          '물폭탄': 2,
#          '예보': 2,
#          '안전': 2,
#          '가평': 2,
#          '포천': 2,
#          '과': 2,
#          '소방': 2,
#          '당국': 2,
#          '사고': 2,
#          '가평읍': 2,
#          '산': 2,
#          '유리': 2,
#          '주인': 2,
#          '명의': 2,
#          '급류': 2,
#          '가평군': 2,
#          '실종자': 2,
#          '범람': 2,
#          '전날': 2,
#          '제': 2,
#          '호': 2,
#          '강수량': 2,
#          '충청': 2,
#          '남부': 2,
#          '북상': 2,
#          '장마전선': 2,
#          '상륙': 2,
#          '속도': 2,
#          '부근': 2,
#          '호우': 2,
#          '전북': 2,
#          '시': 2,
#          '시대': 2,
#          '부동산': 2,
#          '은행권': 2,
#          '거래': 2,
#          '우량': 2,
#          '차주': 2,
#          '비율': 2,
#          '투자': 2,
#          '배': 2,
#          '밤': 1,
#          '사회': 1,
#          '대거': 1,
#          '첫날': 1,
#          '가의': 1,
#          '시각': 1,
#          '한식': 1,
#          '식사': 1,
#          '해': 1,
#          '지면': 1,
#          '찌': 1,
#          '감치': 1,
#          '고깃집': 1,
#          '횟집': 1,
#          '이자카야': 1,
#          '데드라인': 1,
#          '임박': 1,
#          '정리': 1,
#          '라면': 1,
#          '간판': 1,
#          '불빛': 1,
#          '불야성': 1,
#          '번화가': 1,
#          '골목': 1,
#          '깜깜': 1,
#          '정도': 1,
#          '종각역': 1,
#          '부탁': 1,
#          '김씨': 1,
#          '예년': 1,
#          '젠': 1,
#          '반토막': 1,
#          '최모': 1,
#          '친구': 1,
#          '약속': 1,
#          '강제': 1,
#          '귀가': 1,
#          '그냥': 1,
#          '이야기': 1,
#          '누가': 1,
#          '술': 1,
#          '안주': 1,
#          '서울역': 1,
#          '대합실': 1,
#          '한식당': 1,
#          '이전': 1,
#          '패스트푸드': 1,
#          '주문': 1,
#          '국집': 1,
#          '홍': 1,
#          '정복': 1,
#          '차지': 1,
#          '동참': 1,
#          '최대한': 1,
#          '업종': 1,
#          '별로': 1,
#          '희비': 1,
#          '갈리': 1,
#          '기도': 1,
#          '축하': 1,
#          '이체': 1,
#          '성남시': 1,
#          '분당구': 1,
#          '밀집': 1,
#          '일쑤': 1,
#          '화': 1,
#          '불과': 1,
#          '파리': 1,
#          '바게뜨': 1,
#          '별천지': 1,
#          '인석': 1,
#          '테이블': 1,
#          '노트북': 1,
#          '컴퓨터': 1,
#          '업무': 1,
#          '이도': 1,
#          '무풍지대': 1,
#          '인': 1,
#          '소규모': 1,
#          '북적': 1,
#          '소셜네트워크서비스': 1,
#          '인기': 1,
#          '끌': 1,
#          '광주시': 1,
#          '수용': 1,
#          '주차장': 1,
#          '상태': 1,
#          '음료': 1,
#          '방식': 1,
#          '남양주시': 1,
#          '점포': 1,
#          '차로': 1,
#          '송파': 1,
#          '나루': 1,
#          '역': 1,
#          '바람': 1,
#          '교통체증': 1,
#          '프렌': 1,
#          '이즈': 1,
#          '불만': 1,
#          '강화': 1,
#          '원천': 1,
#          '봉쇄': 1,
#          '방향': 1,
#          '선회': 1,
#          '예식': 1,
#          '차례': 1,
#          '연기': 1,
#          '신준하': 1,
#          '김지현': 1,
#          '오프라인': 1,
#          '포기': 1,
#          '모바일': 1,
#          '청첩장': 1,
#          '영상': 1,
#          '홈페이지': 1,
#          '첨부': 1,
#          '아버지': 1,
#          '아버님': 1,
#          '달리기': 1,
#          '신씨': 1,
#          '계기': 1,
#          '문화': 1,
#          '여성': 1,
#          '부모': 1,
#          '참석': 1,
#          '이준희': 1,
#          '가빈': 1,
#          '컴퍼니': 1,
#          '번호': 1,
#          '링크': 1,
#          '형태': 1,
#          '전달': 1,
#          '혼주': 1,
#          '쪽': 1,
#          '입력': 1,
#          '전화번호': 1,
#          '답례': 1,
#          '품': 1,
#          '제한': 1,
#          '조처': 1,
#          '문의': 1,
#          '질병': 1,
#          '관리': 1,
#          '환자': 1,
#          '하루': 1,
#          '닷새': 1,
#          '아래': 1,
#          '정은경': 1,
#          '방대': 1,
#          '본부장': 1,
#          '최후': 1,
#          '방어선': 1,
#          '의료': 1,
#          '기관': 1,
#          '중이': 1,
#          '역학': 1,
#          '여력': 1,
#          '한계': 1,
#          '통제': 1,
#          '판가름': 1,
#          '시기': 1,
#          '이행': 1,
#          '정진호': 1,
#          '채혜선': 1,
#          '권': 1,
#          '혜림': 1,
#          '민정': 1,
#          '사업': 1,
#          '소위': 1,
#          '깡통': 1,
#          '차고': 1,
#          '재기': 1,
#          '정말': 1,
#          '주변': 1,
#          '입': 1,
#          '풀칠': 1,
#          '다행': 1,
#          '인천': 1,
#          '만난': 1,
#          '변기': 1,
#          '세면대': 1,
#          '부속품': 1,
#          '제조업체': 1,
#          '기운': 1,
#          '가동': 1,
#          '평년': 1,
#          '직': 1,
#          '주': 1,
#          '석유파동': 1,
#          '외환위기': 1,
#          '번의': 1,
#          '속': 1,
#          '매번': 1,
#          '오뚝이': 1,
#          '절망': 1,
#          '푸념': 1,
#          '한탄': 1,
#          '산전수전': 1,
#          '도무지': 1,
#          '신종': 1,
#          '코로나바이러스': 1,
#          '감염증': 1,
#          '재간': 1,
#          '량': 1,
#          '걸': 1,
#          '하루하루': 1,
#          '실감': 1,
#          '초상': 1,
#          '중소기업': 1,
#          '면세': 1,
#          '활': 1,
#          '헤어': 1,
#          '론': 1,
#          '원성': 1,
#          '대해': 1,
#          '기적': 1,
#          '평가': 1,
#          '상인': 1,
#          '뭘': 1,
#          '분통': 1,
#          '불구': 1,
#          '몇몇': 1,
#          '분석': 1,
#          '경제성장률': 1,
#          '국가': 1,
#          '후퇴': 1,
#          '통상': 1,
#          '자원부': 1,
#          '월별': 1,
#          '동기': 1,
#          '두': 1,
#          '어가': 1,
#          '통계청': 1,
#          '동행': 1,
#          '순환': 1,
#          '변동': 1,
#          '내리막': 1,
#          '길': 1,
#          '과거': 1,
#          '때': 1,
#          '율': 1,
#          '둔화': 1,
#          '반짝': 1,
#          '곤두박질': 1,
#          '칠': 1,
#          '장담': 1,
#          '무엇': 1,
#          '각종': 1,
#          '장밋빛': 1,
#          '상': 1,
#          '볼멘소리': 1,
#          '현주소': 1,
#          '확인': 1,
#          '명동': 1,
#          '운영': 1,
#          '년': 1,
#          '브레이크': 1,
#          '타임': 1,
#          '인건비': 1,
#          '무급': 1,
#          '휴직': 1,
#          '유통업': 1,
#          '몸': 1,
#          '고통지수': 1,
#          '통계': 1,
#          '외식산업': 1,
#          '연구원': 1,
#          '결과': 1,
#          '응답': 1,
#          '수가': 1,
#          '식품위생': 1,
#          '브랜드': 1,
#          '소리': 1,
#          '안간힘': 1,
#          '서로': 1,
#          '웬': 1,
#          '뒤': 1,
#          '잠시': 1,
#          '활기': 1,
#          '소상': 1,
#          '공인': 1,
#          '표정': 1,
#          '상공': 1,
#          '진흥': 1,
#          '공단': 1,
#          '동향': 1,
#          '전통': 1,
#          '급락': 1,
#          '효과': 1,
#          '소진': 1,
#          '풀이': 1,
#          '기대': 1,
#          '어도': 1,
#          '명도': 1,
#          '적지': 1,
#          '비교': 1,
#          '외국인': 1,
#          '하늘': 1,
#          '길이': 1,
#          '경영': 1,
#          '정상화': 1,
#          '따이공': 1,
#          '중국': 1,
#          '자가': 1,
#          '격리': 1,
#          '해도': 1,
#          '판단': 1,
#          '내년': 1,
#          '기약': 1,
#          '하소연': 1,
#          '비행': 1,
#          '이스타항공': 1,
#          '승무원': 1,
#          '인수합병': 1,
#          '만': 1,
#          '마무리': 1,
#          '일': 1,
#          '거란': 1,
#          '희망고문': 1,
#          '유니폼': 1,
#          '월급': 1,
#          '일자리': 1,
#          '고용': 1,
#          '유지': 1,
#          '근무': 1,
#          '총': 1,
#          '실': 1,
#          '직할': 1,
#          '거': 1,
#          '휴가': 1,
#          '철': 1,
#          '실적': 1,
#          '점': 1,
#          '눈치': 1,
#          '비중': 1,
#          '미만': 1,
#          '수익률': 1,
#          '대중교통': 1,
#          '발달': 1,
#          '요금': 1,
#          '상품화': 1,
#          '수익': 1,
#          '프리미엄': 1,
#          '비즈니스': 1,
#          '국': 1,
#          '출장': 1,
#          '자제': 1,
#          '비어': 1,
#          '지도': 1,
#          '현대': 1,
#          '기아차': 1,
#          '흑자': 1,
#          '기간': 1,
#          '쌍용차': 1,
#          '침체': 1,
#          '붕괴': 1,
#          '불황': 1,
#          '타개': 1,
#          '책': 1,
#          '신차': 1,
#          '출시': 1,
#          '일정': 1,
#          '밀리': 1,
#          '연합': 1,
#          '회': 1,
#          '손실': 1,
#          '물량': 1,
#          '대금': 1,
#          '수령': 1,
#          '조기': 1,
#          '전장': 1,
#          '확보': 1,
#          '조달': 1,
#          '개선': 1,
#          '철강업': 1,
#          '분기': 1,
#          '철강': 1,
#          '제품': 1,
#          '가공': 1,
#          '사': 1,
#          '납품': 1,
#          '대기업': 1,
#          '철근': 1,
#          '형강': 1,
#          '전멸': 1,
#          '수도': 1,
#          '근거': 1,
#          '되풀이': 1,
#          '갈등': 1,
#          '내외': 1,
#          '요인': 1,
#          '불확실': 1,
#          '최소': 1,
#          '지원': 1,
#          '김정식': 1,
#          '연세대': 1,
#          '학부': 1,
#          '교수': 1,
#          '대외': 1,
#          '의존': 1,
#          '임': 1,
#          '소형': 1,
#          '윤태석': 1,
#          '류종은': 1,
#          '맹하': 1,
#          '경': 1,
#          '곳곳': 1,
#          '수해': 1,
#          '초비상': 1,
#          '천안': 1,
#          '호우경보': 1,
#          '가운데': 1,
#          '아산시': 1,
#          '온천': 1,
#          '관광': 1,
#          '사거리': 1,
#          '독자': 1,
#          '제공': 1,
#          '뉴시스': 1,
#          '재산': 1,
#          '각별': 1,
#          '주의': 1,
#          '요구': 1,
#          '각': 1,
#          '지방자치단체': 1,
#          '계속': 1,
#          '게릴라': 1,
#          '평택': 1,
#          '신고': 1,
#          '평택시': 1,
#          '청북읍': 1,
#          '사리': 1,
#          '반도체': 1,
#          '장비': 1,
#          '건물': 1,
#          '뒤편': 1,
#          '야산': 1,
#          '가건물': 1,
#          '천막': 1,
#          '만인': 1,
#          '구조해': 1,
#          '병원': 1,
#          '끝내': 1,
#          '무동': 1,
#          '여': 1,
#          '딸': 1,
#          '손자': 1,
#          '베트남인': 1,
#          '매몰': 1,
#          '시신': 1,
#          '수습': 1,
#          '밭': 1,
#          '린': 1,
#          '청평면': 1,
#          '농민': 1,
#          '사망자': 1,
#          '강타': 1,
#          '중장비': 1,
#          '동원': 1,
#          '작업': 1,
#          '벌이': 1,
#          '뉴스': 1,
#          '충북': 1,
#          '가구': 1,
#          '재민': 1,
#          '제방': 1,
#          '일시': 1,
#          '대피': 1,
#          '인원': 1,
#          '비닐하우스': 1,
#          '동이': 1,
#          '저수지': 1,
#          '교량': 1,
#          '파손': 1,
#          '농경': 1,
#          '댐': 1,
#          '충주댐': 1,
#          '대청댐': 1,
#          '감당': 1,
#          '방류': 1,
#          '여주': 1,
#          '청미': 1,
#          '복': 1,
#          '남양주': 1,
#          '왕숙천': 1,
#          '영평': 1,
#          '홍수': 1,
#          '보가': 1,
#          '기해': 1,
#          '심각': 1,
#          '격상': 1,
#          '대처': 1,
#          '점검': 1,
#          '회의': 1,
#          '추가': 1,
#          '지자체': 1,
#          '총력': 1,
#          '당부': 1,
#          '하구핏': 1,
#          '서해': 1,
#          '강원영동': 1,
#          '경북': 1,
#          '줄곧': 1,
#          '송민섭': 1,
#          '남혜정': 1,
#          '박현준': 1,
#          '세상': 1,
#          '예측': 1,
#          '동반': 1,
#          '유례': 1,
#          '설상가상': 1,
#          '벌써': 1,
#          '엎친': 1,
#          '친': 1,
#          '격': 1,
#          '필리핀': 1,
#          '동쪽': 1,
#          '생': 1,
#          '남북': 1,
#          '동서로': 1,
#          '모양': 1,
#          '강수': 1,
#          '형성': 1,
#          '매우': 1,
#          '편차': 1,
#          '북한': 1,
#          '접경': 1,
#          '지대': 1,
#          '강물': 1,
#          '필요': 1,
#          '한반도': 1,
#          '일대': 1,
#          '일본': 1,
#          '오키나와': 1,
#          '서쪽': 1,
#          '통해': 1,
#          '시속': 1,
#          '부산': 1,
#          '남서쪽': 1,
#          '지리산': 1,
#          '폭우': 1,
#          '강풍': 1,
#          '인적': 1,
#          '집중': 1,
#          '곡성군': 1,
#          '오산면': 1,
#          '장수': 1,
#          '광주': 1,
#          '북구': 1,
#          '남원': 1,
#          '거창': 1,
#          '담양': 1,
#          '화순': 1,
#          '화재': 1,
#          '산림청': 1,
#          '방지원': 1,
#          '제외': 1,
#          '군': 1,
#          '구': 1,
#          '경보': 1,
#          '주의보': 1,
#          '건의': 1,
#          '정': 1,
#          '현수': 1,
#          '오주환': 1,
#          '예': 1,
#          '적금': 1,
#          '수단': 1,
#          '보관': 1,
#          '금고': 1,
#          '한국은행': 1,
#          '발표': 1,
#          '금융기관': 1,
#          '가중': 1,
#          '정기예금': 1,
#          '기준금리': 1,
#          '덩달아': 1,
#          '일제': 1,
#          '담보': 1,
#          '대로': 1,
#          '유독': 1,
#          '담대': 1,
#          '규제': 1,
#          '매매': 1,
#          '전세': 1,
#          '편': 1,
#          '신용등급': 1,
#          '현상': 1,
#          '최대': 1,
#          '사자': 1,
#          '패닉': 1,
#          '바잉': 1,
#          '범': 1,
#          '해석': 1,
#          '워낙': 1,
#          '도나': 1,
#          '빚투': 1,
#          '신용거래': 1,
#          '융자': 1,
#          '잔액': 1,
#          '경신': 1,
#          '증시': 1,
#          '대기': 1,
#          '투자자': 1,
#          '탁': 1,
#          '금도': 1,
#          '탁금': 1,
#          '이기': 1,
#          '훈': 1,
#          '조선일보': 1})

# %%
#워드 클라우드

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)


wc = WordCloud("C:/windows/fonts/malgun.ttf",
               background_color = "white",
               max_words = 2000)
               #stopwords = stopwords)
wc = wc.generate_from_frequencies(counter) # str자료만 가능, list자료는 안됨

#matplotlib로 시작화(1)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# ### [미션] 기사별 워드 클라우드 표시

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np

#단어빈도수 세기
news=pd.read_csv('./data/전처리_샘플뉴스.csv')
okt=Okt()

#워드 클라우드 생성
wc = WordCloud("C:/windows/fonts/malgun.ttf",
               width=300,
               height=300,
               background_color = "white",
               max_words = 50)
               #stopwords = stopwords)
news_nouns=news['text'].apply(okt.nouns)

# %%
news_nouns
# Out:
# 0    [서울, 밤, 수도권, 대상, 사회, 거리, 두기, 단계, 시행, 음식점, 등, 오...
# 1    [동안, 사업, 소위, 깡통, 세, 번, 차고, 재기, 이번, 위기, 정말, 빚, ...
# 2    [곳곳, 수해, 초비상, 오전, 충남, 천안, 아산, 지역, 호우경보, 발령, 가운...
# 3    [예측, 물폭탄, 동반, 장마, 유례, 설상가상, 사흘, 전국, 최고, 이상, 비,...
# 4    [대출, 금리, 사상, 최저, 은행, 예금, 사상, 첫, 금리, 시대, 은행, 예금...
# Name: text, dtype: object

# %%
plt.figure(figsize=(30, 10))
for i, nouns in enumerate(news_nouns):
    counter = Counter(nouns)
    wc = wc.generate_from_frequencies(counter) 
    plt.subplot(1, 5, i+1)
    plt.imshow(wc)
    plt.axis('off')   

plt.show()
